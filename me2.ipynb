# %% [markdown]
# # Bayesian linear regression with measurement error
# ---
# Measurement error is a pervasive issue in various fields of research, impacting the reliability and validity of statistical analyses. The Bayesian Measurement Error Model offers a powerful framework for addressing measurement error, providing a flexible and robust approach to estimate true values while accounting for measurement imprecision.

# %%
import numpy as np
import pandas as pd
import scipy as sp

# %% [markdown]
# ### Resources
#
# Here list of useful resources:
#
# + [STAN guide](https://mc-stan.org/docs/2_18/stan-users-guide/bayesian-measurement-error-model.html)
# + [STAN forums](https://discourse.mc-stan.org/t/classical-vs-berkson-measurement-error/34611)
